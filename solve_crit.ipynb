# %%
import jax
import jax.numpy as jnp
import numpy as np
import equinox as eqx
from diffrax import diffeqsolve, ODETerm, Tsit5, SaveAt

# --- Define RHS network architecture with rho included ---
class RHS(eqx.Module):
    mlp: eqx.nn.MLP
    def __init__(self, key=None):
        dummy_key = jax.random.PRNGKey(0) if key is None else key
        self.mlp = eqx.nn.MLP(in_size=265, out_size=262, width_size=512, depth=4, key=dummy_key)

    def __call__(self, P, H, rho, z):
        x = jnp.concatenate([P, H, rho, jnp.atleast_1d(z)])
        return self.mlp(x)

ys_list = []
for i in range(1):
    # --- Load model ---
    model_path = f"/srv/scratch2/taylor.4264/odd_emu/models/learned_model_crit_{i}.eqx"
    model = RHS()
    model_params = eqx.tree_deserialise_leaves(model_path, model)
    model = eqx.combine(model_params, model)

    # --- Load H(z), rho_crit(z), and pk initial condition ---
    Hz_all = np.load("/srv/scratch2/taylor.4264/odd_emu/batched/Hz_all.npy")       # (30000, 100)
    pk_all = np.load("/srv/scratch2/taylor.4264/odd_emu/batched/pk_nl_all.npy")    # (30000, 100, 262)
    z_grid = np.load("/srv/scratch2/taylor.4264/odd_emu/batched/z.npy")            # (100,)
    rho_all = np.load("/srv/scratch2/taylor.4264/odd_emu/batched/rho_crit_all.npy")    # (30000, 100)

    # Use first sample as reference (reverse for increasing time)
    Hz_ref = Hz_all[0][::-1]
    rho_ref = rho_all[0][::-1]
    z_grid_rev = z_grid[::-1]

    # --- Normalize H(z) and log10(rho_crit(z)) using training stats ---
    H_mean, H_std = jnp.mean(Hz_all), jnp.std(Hz_all)
    log_rho_all = jnp.log10(rho_all + 1e-30)
    log_rho_mean, log_rho_std = jnp.mean(log_rho_all), jnp.std(log_rho_all)

    log_rho_ref = jnp.log10(rho_ref + 1e-30)

    def H_func(z):
        return (jnp.interp(z, z_grid_rev, Hz_ref) - H_mean) / H_std

    def rho_func(z):
        return (jnp.interp(z, z_grid_rev, log_rho_ref) - log_rho_mean) / log_rho_std

    # --- Initial conditions ---
    P0 = pk_all[28, -1]              
    y0 = jnp.log(jnp.array(P0))     # log P at z_max

    z0 = float(z_grid[-1])
    z1 = float(z_grid[0])
    ts = jnp.linspace(z0, z1, 100)  # forward in time

    # --- Define RHS ---
    def rhs(z, P, args):
        model, H_fn, rho_fn = args
        H_z = jnp.atleast_1d(H_fn(z))
        rho_z = jnp.atleast_1d(rho_fn(z))
        return model(P, H_z, rho_z, z)

    # --- Integrate ---
    term = ODETerm(rhs)
    solver = Tsit5()
    saveat = SaveAt(ts=ts)

    sol = diffeqsolve(
        term,
        solver,
        t0=z0,
        t1=z1,
        dt0=-1e-2,
        y0=y0,
        args=(model, H_func, rho_func),
        saveat=saveat
    )

    print("Integrated P(z) shape:", sol.ys.shape)
    Pz = jnp.exp(sol.ys)
    ys_list.append(Pz)
# Out:
# Integrated P(z) shape: (100, 262)

# %%
from matplotlib import pyplot as plt
plt.pcolormesh(sol.ys)

# %%
parent_dir = "/srv/scratch2/taylor.4264/odd_emu/batched"
k = np.load(parent_dir + "/k.npy")  # (262,)'')

# %%
plt.plot(k, Pz[0])
plt.plot(k, pk_all[:,::-1][28, 0])
plt.xscale('log')
plt.yscale('log')
plt.title('z=5.0')
# Out:
# Text(0.5, 1.0, 'z=5.0')

# %%
plt.plot(k, Pz[10])
plt.plot(k, pk_all[:,::-1][28, 10])
plt.xscale('log')
plt.yscale('log')
plt.title('z=4')
# Out:
# Text(0.5, 1.0, 'z=4')

# %%
combined = np.average(np.array(ys_list), axis = 0)
#  1.14648926e+03 1.11452478e+03 1.09211560e+03 1.06173376e+03
#  1.03448401e+03 1.01079730e+03 9.95409607e+02 9.70006287e+02
#  9.43072815e+02 9.20775085e+02 9.02725464e+02 8.75960938e+02
#  8.53908081e+02 8.37930054e+02 8.16585449e+02 8.02512878e+02
#  7.76882202e+02 7.63824890e+02 7.42021973e+02 7.25693420e+02
#  7.10979919e+02 6.92343994e+02 6.74793762e+02 6.56439636e+02
#  6.41990112e+02 6.27167236e+02 6.12412231e+02 5.95998352e+02
#  5.84171692e+02 5.74916687e+02 5.59607300e+02 5.48045471e+02
#  5.38204712e+02 5.25171448e+02 5.14169922e+02 5.01740662e+02
#  4.92268707e+02 4.81871796e+02 4.70219757e+02 4.60077698e+02
#  4.50549896e+02 4.40088776e+02 4.28848755e+02 4.18784668e+02
#  4.10240540e+02 3.98731934e+02 3.88979156e+02 3.79937286e+02
#  3.70389496e+02 3.60887054e+02 3.52222839e+02 3.42902008e+02
#  3.33721069e+02 3.25154449e+02 3.16497894e+02 3.08565918e+02
#  3.00516602e+02 2.92227081e+02 2.84215179e+02 2.76661743e+02
#  2.69426422e+02 2.61203064e+02 2.54053223e+02 2.46609665e+02
#  2.39277725e+02 2.32672119e+02 2.25770706e+02 2.19049026e+02
#  2.12605942e+02 2.06266846e+02 2.00046753e+02 1.94028015e+02
#  1.88164520e+02 1.82032028e+02 1.76543076e+02 1.71194260e+02
#  1.65668564e+02 1.60428131e+02 1.55273178e+02 1.50414078e+02
#  1.45616714e+02 1.40905930e+02 1.36264908e+02 1.31779327e+02
#  1.27357452e+02 1.23098694e+02 1.19145103e+02 1.15096291e+02
#  1.11228325e+02 1.07523415e+02 1.03899841e+02 1.00335449e+02
#  9.68852081e+01 9.35032959e+01 9.03768616e+01 8.71151123e+01
#  8.41970825e+01 8.11932755e+01 7.83846817e+01 7.56619873e+01
#  7.29184647e+01 7.03567734e+01 6.77493286e+01 6.54289856e+01
#  6.30700874e+01 6.07746277e+01 5.85351944e+01 5.64507523e+01
#  5.44250374e+01 5.24161606e+01]

# %%
plt.plot(k, ys_list[0][99] / pk_all[:,::-1][28, 99])
plt.xscale('log')

# %%
plt.plot(k, sol.ys[99] / pk_all[:,::-1][28, 99])
plt.xscale('log')

# %%
import jax
import jax.numpy as jnp
import numpy as np
import equinox as eqx
from diffrax import diffeqsolve, ODETerm, Tsit5, SaveAt

for ii in range(10):
    # --- Define RHS network architecture ---
    class RHS(eqx.Module):
        mlp: eqx.nn.MLP
        def __init__(self, key=None):
            dummy_key = jax.random.PRNGKey(0) if key is None else key
            self.mlp = eqx.nn.MLP(in_size=264, out_size=262, width_size=512, depth=4, key=dummy_key)

        def __call__(self, P, H, z):
            x = jnp.concatenate([P, H, jnp.atleast_1d(z)])
            return self.mlp(x)

    # --- Load trained model ---
    model_path = "/srv/scratch2/taylor.4264/odd_emu/models/learned_model_low_z.eqx"
    model = RHS()
    model_params = eqx.tree_deserialise_leaves(model_path, model)
    model = eqx.combine(model_params, model)

    # --- Load H(z) and P(z) initial condition ---
    Hz_all = np.load("/srv/scratch2/taylor.4264/odd_emu/batched_low_z/Hz_all.npy")     # (30000, 100)
    pk_all = np.load("/srv/scratch2/taylor.4264/odd_emu/batched_low_z/pk_nl_all.npy")  # (30000, 100, 262)
    z_grid = np.load("/srv/scratch2/taylor.4264/odd_emu/batched_low_z/z.npy")          # (100,)

    # Use first sample as reference
    Hz_ref = Hz_all[0][::-1]        # reverse for decreasing z
    z_grid_rev = z_grid[::-1]       # high → low redshift

    # Interpolated function H(z), valid for decreasing z
    def H_func(z):
        return jnp.interp(z, z_grid_rev, Hz_ref)

    # Initial condition at z_max
    P0 = pk_all[ii, -1]              # corresponds to highest redshift z = z_grid[-1]

    # Time range: high z to low z
    z0 = float(z_grid[-1])          # e.g., z = 5
    z1 = float(z_grid[0])           # e.g., z = 0
    ts = jnp.linspace(z0, z1, 100)  # forward in time

    # --- Define RHS for ODE
    def rhs(z, P, args):
        model, H_fn = args
        H_z = jnp.atleast_1d(H_fn(z))
        return model(P, H_z, z)

    # --- Solve ODE
    term = ODETerm(rhs)
    solver = Tsit5()
    saveat = SaveAt(ts=ts)

    sol = diffeqsolve(
        term,
        solver,
        t0=z0,
        t1=z1,
        dt0=-1e-2,  # negative because z is decreasing
        y0 = jnp.log(jnp.array(P0)),
        args=(model, H_func),
        saveat=saveat
    )

    print("Integrated P(z) shape (forward in time):", sol.ys.shape)
    plt.plot(k, sol.ys[99] / pk_all[:,::-1][ii, 99])
    plt.xscale('log')
# Out:
# Integrated P(z) shape (forward in time): (100, 262)
# Integrated P(z) shape (forward in time): (100, 262)
# Integrated P(z) shape (forward in time): (100, 262)
# Integrated P(z) shape (forward in time): (100, 262)
# Integrated P(z) shape (forward in time): (100, 262)
# Integrated P(z) shape (forward in time): (100, 262)
# Integrated P(z) shape (forward in time): (100, 262)
# Integrated P(z) shape (forward in time): (100, 262)
# Integrated P(z) shape (forward in time): (100, 262)
# Integrated P(z) shape (forward in time): (100, 262)

# %%
import jax
import jax.numpy as jnp
import numpy as np
import equinox as eqx
from diffrax import diffeqsolve, ODETerm, Tsit5, SaveAt

for ii in range(10):
    # --- Define RHS network architecture ---
    class RHS(eqx.Module):
        mlp: eqx.nn.MLP
        def __init__(self, key=None):
            dummy_key = jax.random.PRNGKey(0) if key is None else key
            self.mlp = eqx.nn.MLP(in_size=264, out_size=262, width_size=512, depth=4, key=dummy_key)

        def __call__(self, P, H, z):
            x = jnp.concatenate([P, H, jnp.atleast_1d(z)])
            return self.mlp(x)

    # --- Load trained model ---
    model_path = "/srv/scratch2/taylor.4264/odd_emu/models/learned_model_low_z.eqx"
    model = RHS()
    model_params = eqx.tree_deserialise_leaves(model_path, model)
    model = eqx.combine(model_params, model)

    # --- Load H(z) and P(z) initial condition ---
    Hz_all = np.load("/srv/scratch2/taylor.4264/odd_emu/batched_low_z/Hz_all.npy")     # (30000, 100)
    pk_all = np.load("/srv/scratch2/taylor.4264/odd_emu/batched_low_z/pk_nl_all.npy")  # (30000, 100, 262)
    z_grid = np.load("/srv/scratch2/taylor.4264/odd_emu/batched_low_z/z.npy")          # (100,)

    # Use first sample as reference
    Hz_ref = Hz_all[0][::-1]        # reverse for decreasing z
    z_grid_rev = z_grid[::-1]       # high → low redshift

    # Interpolated function H(z), valid for decreasing z
    def H_func(z):
        return jnp.interp(z, z_grid_rev, Hz_ref)

    # Initial condition at z_max
    P0 = pk_all[ii, -1]              # corresponds to highest redshift z = z_grid[-1]

    # Time range: high z to low z
    z0 = float(z_grid[-1])          # e.g., z = 5
    z1 = float(z_grid[0])           # e.g., z = 0
    ts = jnp.linspace(z0, z1, 100)  # forward in time

    # --- Define RHS for ODE
    def rhs(z, P, args):
        model, H_fn = args
        H_z = jnp.atleast_1d(H_fn(z))
        return model(P, H_z, z)

    # --- Solve ODE
    term = ODETerm(rhs)
    solver = Tsit5()
    saveat = SaveAt(ts=ts)

    sol = diffeqsolve(
        term,
        solver,
        t0=z0,
        t1=z1,
        dt0=-1e-2,  # negative because z is decreasing
        y0=jnp.array(P0),
        args=(model, H_func),
        saveat=saveat
    )

    print("Integrated P(z) shape (forward in time):", sol.ys.shape)
    plt.plot(k, sol.ys[99] / pk_all[:,::-1][ii, 99])
    #plt.xscale('log')
# Out:
# Integrated P(z) shape (forward in time): (100, 262)
# Integrated P(z) shape (forward in time): (100, 262)
# Integrated P(z) shape (forward in time): (100, 262)
# Integrated P(z) shape (forward in time): (100, 262)
# Integrated P(z) shape (forward in time): (100, 262)
# Integrated P(z) shape (forward in time): (100, 262)
# Integrated P(z) shape (forward in time): (100, 262)
# Integrated P(z) shape (forward in time): (100, 262)
# Integrated P(z) shape (forward in time): (100, 262)
# Integrated P(z) shape (forward in time): (100, 262)
